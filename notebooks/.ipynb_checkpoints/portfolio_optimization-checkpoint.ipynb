# %%
# Import necessary modules
from src.data_collection import fetch_stock_data, fetch_fama_french_factors, fetch_fed_rate_decisions
from src.factor_modeling import calculate_asset_returns
from src.fed_analysis import identify_fed_regimes
from src.optimization import backtest_regime_strategies
from src.visualization import create_portfolio_performance_dashboard, create_performance_summary_table


# Fetch data
tickers = ['SPY', 'QQQ', 'IWM', 'GLD', 'TLT']
stock_data = fetch_stock_data(tickers, '2010-01-01', '2023-12-31')
ff_factors = fetch_fama_french_factors(frequency='daily')
fed_decisions = fetch_fed_rate_decisions()


# Calculate returns from price data
returns = calculate_asset_returns(stock_data)

# Identify Fed regimes
fed_regimes = identify_fed_regimes(fed_decisions)

# You can print these to verify they look correct
print(f"Returns data shape: {returns.shape}")
print(f"Fed regimes data shape: {fed_regimes.shape}")



backtest_results = backtest_regime_strategies(
    returns, 
    fed_regimes, 
    factor_data=ff_factors, 
    rebalance_freq=21
)

# Create performance dashboard
dashboard = create_portfolio_performance_dashboard(
    backtest_results['strategy_returns'],
    backtest_results['strategy_weights'],
    backtest_results['benchmark_returns']
)

# Create performance summary table
metrics_table = create_performance_summary_table(backtest_results['performance_metrics'])

# Create a comparison chart of cumulative returns
plt.figure(figsize=(12, 8))
for name, returns_series in backtest_results['strategy_returns'].items():
    cum_returns = (1 + returns_series).cumprod()
    plt.plot(cum_returns.index, cum_returns, label=name)
plt.title('Cumulative Performance of Portfolio Strategies')
plt.xlabel('Date')
plt.ylabel('Growth of $1')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2025-03-06 09:22:36,265 - src.data_collection - INFO - Fetching stock data for 5 tickers from 2010-01-01 to 2023-12-31
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  5 of 5 completed
# 2025-03-06 09:22:36,661 - src.data_collection - INFO - Raw stock data saved to /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/data/raw/stock_prices_2010-01-01_to_2023-12-31.csv
# 2025-03-06 09:22:36,661 - src.data_collection - INFO - Fetching Fama-French factors with daily frequency
# Data columns: MultiIndex([( 'Close', 'GLD'),
#             ( 'Close', 'IWM'),
#             ( 'Close', 'QQQ'),
#             ( 'Close', 'SPY'),
#             ( 'Close', 'TLT'),
#             (  'High', 'GLD'),
#             (  'High', 'IWM'),
#             (  'High', 'QQQ'),
#             (  'High', 'SPY'),
#             (  'High', 'TLT'),
#             (   'Low', 'GLD'),
#             (   'Low', 'IWM'),
#             (   'Low', 'QQQ'),
#             (   'Low', 'SPY'),
#             (   'Low', 'TLT'),
#             (  'Open', 'GLD'),
#             (  'Open', 'IWM'),
#             (  'Open', 'QQQ'),
#             (  'Open', 'SPY'),
#             (  'Open', 'TLT'),
#             ('Volume', 'GLD'),
#             ('Volume', 'IWM'),
#             ('Volume', 'QQQ'),
#             ('Volume', 'SPY'),
#             ('Volume', 'TLT')],
#            names=['Price', 'Ticker'])
# Column levels: [['Close', 'High', 'Low', 'Open', 'Volume'], ['GLD', 'IWM', 'QQQ', 'SPY', 'TLT']]
# Level 0 values: ['Close', 'High', 'Low', 'Open', 'Volume']
# Level 1 values: ['GLD', 'IWM', 'QQQ', 'SPY', 'TLT']
# 2025-03-06 09:22:37,653 - src.data_collection - INFO - Raw FF factors zip saved to /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/data/raw/FF_factors_daily.zip
# 2025-03-06 09:22:37,773 - src.data_collection - INFO - Processed FF factors saved to /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer
- src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:38,678 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:38,681 - src.optimization - INFO - Optimization results: Return=1.0000, Risk=0.0116, Sharpe=86.4389
# 2025-03-06 09:22:38,681 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# ...
# 2025-03-06 09:22:39,417 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,418 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,421 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0113, Sharpe=10.1891
# 2025-03-06 09:22:39,422 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,422 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,425 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0121, Sharpe=9.5496
# 2025-03-06 09:22:39,425 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,426 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,429 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0130, Sharpe=8.8792
# 2025-03-06 09:22:39,429 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,430 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,433 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0134, Sharpe=8.6058
# 2025-03-06 09:22:39,433 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,434 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,437 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0138, Sharpe=8.3547
# 2025-03-06 09:22:39,437 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,438 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,441 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0145, Sharpe=7.9375
# 2025-03-06 09:22:39,441 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,442 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,445 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0151, Sharpe=7.6518
# 2025-03-06 09:22:39,446 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,447 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,450 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0156, Sharpe=7.3845
# 2025-03-06 09:22:39,450 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,451 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,454 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0157, Sharpe=7.3426
# 2025-03-06 09:22:39,454 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,455 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,458 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0156, Sharpe=7.4021
# 2025-03-06 09:22:39,458 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,459 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,462 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0152, Sharpe=7.5809
# 2025-03-06 09:22:39,462 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,463 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,466 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0149, Sharpe=7.7106
# 2025-03-06 09:22:39,466 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,467 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,470 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0140, Sharpe=8.2122
# 2025-03-06 09:22:39,471 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,471 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,474 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0133, Sharpe=8.6470
# 2025-03-06 09:22:39,475 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,475 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,478 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0125, Sharpe=9.2539
# 2025-03-06 09:22:39,478 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,479 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,482 - src.optimization - INFO - Optimization results: Return=0.1153, Risk=0.0120, Sharpe=9.5747
# 2025-03-06 09:22:39,482 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,483 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,487 - src.optimization - INFO - Optimization results: Return=0.1258, Risk=0.0116, Sharpe=10.8405
# 2025-03-06 09:22:39,488 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,489 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,493 - src.optimization - INFO - Optimization results: Return=0.1258, Risk=0.0106, Sharpe=11.8252
# 2025-03-06 09:22:39,493 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,494 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,498 - src.optimization - INFO - Optimization results: Return=0.1258, Risk=0.0102, Sharpe=12.3383
# 2025-03-06 09:22:39,498 - src.optimization - INFO - Estimating covariance using ledoit-wolf method
# 2025-03-06 09:22:39,499 - src.optimization - INFO - Performing mean-variance optimization
# 2025-03-06 09:22:39,502 - src.optimization - INFO - Optimization results: Return=0.3394, Risk=0.0070, Sharpe=48.3407
# 2025-03-06 09:22:39,504 - src.optimization - INFO - Calculating portfolio returns
# 2025-03-06 09:22:39,565 - src.optimization - INFO - Calculating portfolio returns
# /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/src/optimization.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[np.float64(-0.007694116688815745) np.float64(0.00011696101752819727)
#  np.float64(-0.0006075324617353328) np.float64(-0.001017810394051152)
#  np.float64(0.0035377336306805776) np.float64(0.0018624604497130203)
#  np.float64(0.004200343671451638) np.float64(-0.0006227216124040451)
#  np.float64(0.0011291970271885155) np.float64(0.0012295201314979033)
#  np.float64(-0.007493167921151504) np.float64(-0.010296990735172063)
#  np.float64(-0.001091546113916615) np.float64(0.004444802737445036)
#  np.float64(0.002201995344556522) np.float64(0.003620143174653365)
#  np.float64(-0.0017176130345157264) np.float64(-0.008730263846163221)
#  np.float64(0.0017148780034611853) np.float64(0.012012210258561395)
#  np.float64(-0.0019413862166744124) np.float64(0.002525529909793302)]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   portfolio_returns.loc[start_date:end_date] = period_portfolio_returns
# 2025-03-06 09:22:39,630 - src.optimization - INFO - Calculating portfolio returns
# /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/src/optimization.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[np.float64(-0.007694116688821162) np.float64(0.00011696101751992351)
#  np.float64(-0.0006075324617348165) np.float64(-0.0010178103940499561)
#  np.float64(0.0035377336306842144) np.float64(0.0018624604497121894)
#  np.float64(0.00420034367145008) np.float64(-0.0006227216124021549)
#  np.float64(0.0011291970271849693) np.float64(0.0012295201314969752)
#  np.float64(-0.007493167921151223) np.float64(-0.010296990735182289)
#  np.float64(-0.0010915461139143104) np.float64(0.00444480273744512)
#  np.float64(0.0022019953445603147) np.float64(0.0036201431746504037)
#  np.float64(-0.0017176130345177847) np.float64(-0.00873026384616067)
#  np.float64(0.0017148780034582864) np.float64(0.01201221025856325)
#  np.float64(-0.001941386216675234) np.float64(0.002525529909792579)]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   portfolio_returns.loc[start_date:end_date] = period_portfolio_returns
# 2025-03-06 09:22:39,696 - src.optimization - INFO - Calculating portfolio returns
# /Users/gabescott/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/src/optimization.py:480: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[np.float64(-0.0047115858026260315) np.float64(0.005427062576209655)
#  np.float64(-0.0005804942703187065) np.float64(-0.0020331097596230302)
#  np.float64(0.0030109438090931344) np.float64(0.002146683089727211)
#  np.float64(0.006637207410954698) np.float64(0.0003985171221244664)
#  np.float64(0.006013836809205773) np.float64(0.0011077326589117474)
#  np.float64(-0.013335826682981501) np.float64(-0.007033135411888656)
#  np.float64(-0.002834474587780923) np.float64(0.008113871702623046)
#  np.float64(0.0020009851617032635) np.float64(0.006015204509106585)
#  np.float64(0.003910585450423783) np.float64(-0.019656037137174728)
#  np.float64(0.005039446797737661) np.float64(0.016860211142847005)
#  np.float64(-0.002153535629433304) np.float64(0.0014216703979380843)]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   portfolio_returns.loc[start_date:end_date] = period_portfolio_returns
# 2025-03-06 09:22:39,759 - src.optimization - INFO - Calculating performance metrics
# 2025-03-06 09:22:39,761 - src.optimization - INFO - Calculating performance metrics
# 2025-03-06 09:22:39,766 - src.optimization - INFO - Calculating performance metrics
# 2025-03-06 09:22:39,770 - src.optimization - INFO - Calculating performance metrics
# 2025-03-06 09:22:39,775 - src.optimization - INFO - Calculating performance metrics
# 2025-03-06 09:22:39,776 - src.optimization - INFO - Plotting performance comparison
# 2025-03-06 09:22:39,836 - src.visualization - INFO - Creating portfolio performance dashboard
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 36
#      28 backtest_results = backtest_regime_strategies(
#      29     returns,
#      30     fed_regimes,
#      31     factor_data=ff_factors,
#      32     rebalance_freq=21
#      33 )
#      35 # Create performance dashboard
# ---> 36 dashboard = create_portfolio_performance_dashboard(
#      37     backtest_results['strategy_returns'],
#      38     backtest_results['strategy_weights'],
#      39     backtest_results['benchmark_returns']
#      40 )
#      42 # Create performance summary table
#      43 metrics_table = create_performance_summary_table(backtest_results['performance_metrics'])
#
# File ~/GitHub-Portfolio-Project/FF-FedTiming-Portfolio-Optimizer/src/visualization.py:460, in create_portfolio_performance_dashboard(strategy_returns, weights, benchmark_returns, save_path)
#     458 # Add rolling return traces
#     459 for name, roll_ret in rolling_returns.items():
# --> 460     fig.add_trace(
#     461         go.Scatter(
#     462             x=roll_ret.index,
#     463             y=roll_ret,
#     464             name=f"{name} 3M",
#     465             hovertemplate=f"{name} 3M Return: %{{y:.2%}}<extra></extra>",
#     466             visible='legendonly'
#     467         ),
#     468         row=2, col=2
#     469     )
#     471 # Add return distribution
#     472 for name, returns in all_returns.items():
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/graph_objs/_figure.py:917, in Figure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#     842 def add_trace(
#     843     self, trace, row=None, col=None, secondary_y=None, exclude_empty_subplots=False
#     844 ) -> "Figure":
#     845     """
#     846
#     847     Add a trace to the figure
#    (...)
#     915
#     916     """
# --> 917     return super(Figure, self).add_trace(
#     918         trace, row, col, secondary_y, exclude_empty_subplots
#     919     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:2106, in BaseFigure.add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#    2097         self.add_trace(
#    2098             trace,
#    2099             row=r,
#    (...)
#    2102             exclude_empty_subplots=exclude_empty_subplots,
#    2103         )
#    2104     return self
# -> 2106 return self.add_traces(
#    2107     data=[trace],
#    2108     rows=[row] if row is not None else None,
#    2109     cols=[col] if col is not None else None,
#    2110     secondary_ys=[secondary_y] if secondary_y is not None else None,
#    2111     exclude_empty_subplots=exclude_empty_subplots,
#    2112 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/graph_objs/_figure.py:997, in Figure.add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#     921 def add_traces(
#     922     self,
#     923     data,
#    (...)
#     927     exclude_empty_subplots=False,
#     928 ) -> "Figure":
#     929     """
#     930
#     931     Add traces to the figure
#    (...)
#     995
#     996     """
# --> 997     return super(Figure, self).add_traces(
#     998         data, rows, cols, secondary_ys, exclude_empty_subplots
#     999     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:2236, in BaseFigure.add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#    2234 if rows is not None:
#    2235     for trace, row, col, secondary_y in zip(data, rows, cols, secondary_ys):
# -> 2236         self._set_trace_grid_position(trace, row, col, secondary_y)
#    2238 if exclude_empty_subplots:
#    2239     data = list(
#    2240         filter(
#    2241             lambda trace: self._subplot_not_empty(
#    (...)
#    2245         )
#    2246     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:2328, in BaseFigure._set_trace_grid_position(self, trace, row, col, secondary_y)
#    2325 from plotly._subplots import _set_trace_grid_reference
#    2327 grid_ref = self._validate_get_grid_ref()
# -> 2328 return _set_trace_grid_reference(
#    2329     trace, self.layout, grid_ref, row, col, secondary_y
#    2330 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/_subplots.py:1415, in _set_trace_grid_reference(trace, layout, grid_ref, row, col, secondary_y)
#    1413     for k in trace_kwargs:
#    1414         if k not in trace:
# -> 1415             raise ValueError(
#    1416                 """\
#    1417 Trace type '{typ}' is not compatible with subplot type '{subplot_type}'
#    1418 at grid position ({row}, {col})
#    1419
#    1420 See the docstring for the specs argument to plotly.subplots.make_subplots
#    1421 for more information on subplot types""".format(
#    1422                     typ=trace.type,
#    1423                     subplot_type=subplot_refs[0].subplot_type,
#    1424                     row=row,
#    1425                     col=col,
#    1426                 )
#    1427             )
#    1429     # Update trace reference
#    1430     trace.update(trace_kwargs)
#
# ValueError: Trace type 'scatter' is not compatible with subplot type 'domain'
# at grid position (2, 2)
#
# See the docstring for the specs argument to plotly.subplots.make_subplots
# for more information on subplot types
